# %%
from google.colab import drive

drive.mount("/content/my_drive/")
# Out:
# Mounted at /content/my_drive/

# %%
cd /content/my_drive/MyDrive/Neurips23/Integrating-Spatial-Transform-Networks-with-PaDim-Architecture/notebooks/
# Out:
# /content/my_drive/MyDrive/Neurips23/Integrating-Spatial-Transform-Networks-with-PaDim-Architecture/notebooks

# %%
#!pip install pytorch_msssim

# %%
#!pip install --upgrade wandb

# %%
! python train_padim.py --arch resnet18 --use_stn 1 --path_model_stn ../results/models/v1_mse/checkpoint_best_model.pth
# Out:
# args.device: 0
# Namespace(data_path='../data', experiment_name='exp-padim', batch_size=128, learning_rate=0.0005, path_results='../results/padim_results', arch='resnet18', use_stn=1, path_model_stn='../results/models/v1_mse/checkpoint_best_model.pth', device='0')
# wandb: Currently logged in as: cristian-ml (ml_projects). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.16.1
# wandb: Run data is saved locally in /content/my_drive/MyDrive/Neurips23/Integrating-Spatial-Transform-Networks-with-PaDim-Architecture/notebooks/wandb/run-20231209_221837-7mt018q6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run exp-padim
# wandb: ⭐️ View project at https://wandb.ai/ml_projects/neurips_23
# wandb: 🚀 View run at https://wandb.ai/ml_projects/neurips_23/runs/7mt018q6
# ...

# %%
# !python train_padim.py --arch resnet18 --use_stn_mask 1 --use_stn 1 --path_model_stn ../results/models/v1_mse_l1/checkpoint_best_model.pth

# %%
# !python train_padim.py --arch wide_resnet50_2 --use_stn_mask 0 --use_stn 0 --path_model_stn ../results/models/v1_mse_l1/checkpoint_best_model.pth

# %%
# !python train_padim.py --arch wide_resnet50_2 --use_stn_mask 0 --use_stn 1 --path_model_stn ../results/models/v1_mse_l1/checkpoint_best_model.pth

# %%
# !python train_padim.py --arch wide_resnet50_2 --use_stn_mask 1 --use_stn 1 --path_model_stn ../results/models/v1_mse_l1/checkpoint_best_model.pth

# %%
# !python train_padim.py --arch wide_resnet50_2 --use_stn_mask 0 --use_stn 1 --path_model_stn ../results/models/v1_mse/checkpoint_best_model.pth

# %%
# !python train_padim.py --arch wide_resnet50_2 --use_stn_mask 1 --use_stn 1 --path_model_stn ../results/models/v1_mse/checkpoint_best_model.pth
